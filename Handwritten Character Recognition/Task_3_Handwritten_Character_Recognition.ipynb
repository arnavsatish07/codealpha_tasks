# %% [markdown]
# # CodeAlpha Task 3 — Handwritten Character Recognition
#
# The CodeAlpha brief specifies MNIST/EMNIST and CNNs for handwritten character recognition.

# %%
# pip install tensorflow
import tensorflow as tf
from tensorflow.keras import layers,models
import numpy as np

(X_train,y_train),(X_test,y_test)=tf.keras.datasets.mnist.load_data()
X_train=X_train.astype('float32')/255
X_test=X_test.astype('float32')/255
X_train=X_train[...,None]; X_test=X_test[...,None]
print(X_train.shape,X_test.shape)

# %%
model=models.Sequential([
    layers.Input((28,28,1)),
    layers.Conv2D(32,3,activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128,3,activation='relu'),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(.3),
    layers.Dense(10,activation='softmax')
])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=5,batch_size=128,validation_split=.1)
print('Test:',model.evaluate(X_test,y_test))

# %%
import matplotlib.pyplot as plt
pred=np.argmax(model.predict(X_test[:12]),axis=1)
plt.figure(figsize=(12,4))
for i in range(12):
    plt.subplot(2,6,i+1); plt.imshow(X_test[i].squeeze(),cmap='gray'); plt.title(f'P:{pred[i]} / T:{y_test[i]}'); plt.axis('off')
plt.tight_layout(); plt.show()

# %% [markdown]
# The included offline_digits_demo.npz is a lightweight scikit-learn handwritten-digit dataset for inspection. It is not MNIST; the actual CodeAlpha implementation above uses MNIST.
